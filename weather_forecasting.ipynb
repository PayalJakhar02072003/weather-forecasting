# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("zaraavagyan/weathercsv")

df=pd.read_csv(path+"/weather.csv")
df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
df.isnull().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()

# %%
df['RainTomorrow']=LE.fit_transform(df['RainTomorrow'])

# %%
df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
df['RainToday'].nunique()
# Out:
# 2

# %%
df['WindGustDir'].unique()
# Out:
# array(['NW', 'ENE', 'SSE', 'SE', 'E', 'S', 'N', 'WNW', 'ESE', 'NE', 'NNE',
#        'NNW', 'SW', 'W', 'WSW', 'SSW', nan], dtype=object)

# %%
X=df.iloc[:,:-1]
X
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity9am  \
# 0             30.0         SW         NW           6.0  ...           68
# ...

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 361    0
# 362    0
# 363    0
# 364    0
# 365    0
# Name: RainTomorrow, Length: 366, dtype: int64

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
X=sc.fit_transform(X)

# %%
X = pd.get_dummies(X, columns=['WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday'], drop_first=True)
display(X.head())
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0      8.0     24.3       0.0          3.4       6.3           30.0
# 1     14.0     26.9       3.6          4.4       9.7           39.0
# 2     13.7     23.4       3.6          5.8       3.3           85.0
# 3     13.3     15.5      39.8          7.2       9.1           54.0
# 4      7.6     16.1       2.8          5.6      10.6           50.0
#
#    WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  WindDir3pm_NW  \
# 0           6.0            20           68           29  ...           True
# 1           4.0            17           80           36  ...          False
# 2           6.0             6           82           69  ...          False
# 3          30.0            24           62           56  ...          False
# 4          20.0            28           68           49  ...          False
#
#    WindDir3pm_S  WindDir3pm_SE  WindDir3pm_SSE  WindDir3pm_SSW  WindDir3pm_SW  \
# ...

# %%
X = sc.fit_transform(X)
display(X)
# Out:
# array([[ 0.12204713,  0.5612213 , -0.33848522, ..., -0.4472136 ,
#         -0.17602817, -0.46904158],
#        [ 1.11912864,  0.95036308,  0.51459076, ..., -0.4472136 ,
#         -0.17602817,  2.13200716],
#        [ 1.06927456,  0.42651837,  0.51459076, ..., -0.4472136 ,
#         -0.17602817,  2.13200716],
#        ...,
#        [ 0.86985826, -0.09732634, -0.33848522, ..., -0.4472136 ,
#         -0.17602817, -0.46904158],
#        [ 0.86985826,  0.95036308, -0.33848522, ...,  2.23606798,
#         -0.17602817, -0.46904158],
#        [ 0.83662221,  1.44427381, -0.33848522, ...,  2.23606798,
#         -0.17602817, -0.46904158]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# (292, 63)
# (74, 63)
# (292,)
# (74, 63)

# %%
from sklearn.metrics import accuracy_score

# %%
def mlmodel(model,model_name):
    print("----------",model_name,"----------")
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)

    acc_score=accuracy_score(y_test,y_pred)
    return 'Accuracy_Score',acc_score

# %%
from sklearn.svm import SVC

# %%
svm=SVC(kernel='rbf',C=1.0,gamma='scale')

# %%
svm_model=mlmodel(svm,"SVM")
# Out:
# ---------- SVM ----------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1046430500.py in <cell line: 0>()
# ----> 1 svm_model=mlmodel(svm,"SVM")
#
# /tmp/ipython-input-2499307174.py in mlmodel(model, model_name)
#       1 def mlmodel(model,model_name):
#       2     print("----------",model_name,"----------")
# ----> 3     model.fit(X_train,y_train)
#       4     y_pred=model.predict(X_test)
#       5
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     195             check_consistent_length(X, y)
#     196         else:
# ...

# %%
# Impute missing values
for col in ['Sunshine', 'WindGustSpeed', 'WindSpeed9am']:
    df[col].fillna(df[col].mean(), inplace=True)

for col in ['WindGustDir', 'WindDir9am', 'WindDir3pm']:
    df[col].fillna(df[col].mode()[0], inplace=True)

# Verify that there are no more missing values
display(df.isnull().sum())
# Out:
# /tmp/ipython-input-4000558174.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)
# /tmp/ipython-input-4000558174.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
# Redefine X after imputation
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
# Perform one-hot encoding again on the imputed data
X = pd.get_dummies(X, columns=['WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday'], drop_first=True)
display(X.head())
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0      8.0     24.3       0.0          3.4       6.3           30.0
# 1     14.0     26.9       3.6          4.4       9.7           39.0
# 2     13.7     23.4       3.6          5.8       3.3           85.0
# 3     13.3     15.5      39.8          7.2       9.1           54.0
# 4      7.6     16.1       2.8          5.6      10.6           50.0
#
#    WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  WindDir3pm_NW  \
# 0           6.0            20           68           29  ...           True
# 1           4.0            17           80           36  ...          False
# 2           6.0             6           82           69  ...          False
# 3          30.0            24           62           56  ...          False
# 4          20.0            28           68           49  ...          False
#
#    WindDir3pm_S  WindDir3pm_SE  WindDir3pm_SSE  WindDir3pm_SSW  WindDir3pm_SW  \
# ...

# %%
# Scale the data again
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X = sc.fit_transform(X)
display(X)
# Out:
# array([[ 0.12204713,  0.5612213 , -0.33848522, ..., -0.4472136 ,
#         -0.17602817, -0.46904158],
#        [ 1.11912864,  0.95036308,  0.51459076, ..., -0.4472136 ,
#         -0.17602817,  2.13200716],
#        [ 1.06927456,  0.42651837,  0.51459076, ..., -0.4472136 ,
#         -0.17602817,  2.13200716],
#        ...,
#        [ 0.86985826, -0.09732634, -0.33848522, ..., -0.4472136 ,
#         -0.17602817, -0.46904158],
#        [ 0.86985826,  0.95036308, -0.33848522, ...,  2.23606798,
#         -0.17602817, -0.46904158],
#        [ 0.83662221,  1.44427381, -0.33848522, ...,  2.23606798,
#         -0.17602817, -0.46904158]])

# %%
# Split the data again
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
# Now try running the model again
from sklearn.svm import SVC
svm=SVC(kernel='rbf',C=1.0,gamma='scale')
svm_model=mlmodel(svm,"SVM")
print(svm_model)
# Out:
# ---------- SVM ----------
# ('Accuracy_Score', 0.8918918918918919)

# %%
print(svm_model)
# Out:
# ('Accuracy_Score', 0.8918918918918919)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree=DecisionTreeClassifier(max_features=100,random_state=0)

# %%
dtree_model=mlmodel(dtree,"Decision Tree")
# Out:
# ---------- Decision Tree ----------

# %%
print(dtree_model)
# Out:
# ('Accuracy_Score', 1.0)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
ranforest=RandomForestClassifier(n_estimators=100,random_state=0)

# %%
ranforest_model=mlmodel(ranforest,"Random Forest Classifier")
# Out:
# ---------- Random Forest Classifier ----------

# %%
print(ranforest_model)
# Out:
# ('Accuracy_Score', 0.9864864864864865)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=5)

# %%
knn_model=mlmodel(knn,"KNN")
# Out:
# ---------- KNN ----------

# %%
print(knn_model)

# %%
print("Accuracy score of different models\n")
print("SVM : ",svm_model)
print("Decision Tree : ",dtree_model)
print("Random Forest : ",ranforest_model)
print("KNN : ",knn_model)
# Out:
# Accuracy score of different models
#
# SVM :  ('Accuracy_Score', 0.8918918918918919)
# Decision Tree :  ('Accuracy_Score', 1.0)
# Random Forest :  ('Accuracy_Score', 0.9864864864864865)
# KNN :  ('Accuracy_Score', 0.8378378378378378)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb=GaussianNB()

# %%
nb_model=mlmodel(nb,"Naive Bayes")
# Out:
# ---------- Naive Bayes ----------

# %%
print(nb_model)
# Out:
# ('Accuracy_Score', 0.3108108108108108)

# %%
import xgboost as xgb

# %%
xg = xgb.XGBClassifier(objective='multi:softmax', num_class=y.nunique(), n_estimators=100, random_state=42, eval_metric='mlogloss', use_label_encoder=False)

# %%
xg_model=mlmodel(xg,"XGBoost")
# Out:
# ---------- XGBoost ----------
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [09:23:58] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
print(xg_model)
# Out:
# ('Accuracy_Score', 1.0)
